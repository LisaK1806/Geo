# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("TS067-2021-3.csv")

# %%
df
# Out:
#      Lower tier local authorities Code Lower tier local authorities  \
# 0                            E06000001                   Hartlepool
# 1                            E06000001                   Hartlepool
# 2                            E06000001                   Hartlepool
# 3                            E06000001                   Hartlepool
# 4                            E06000001                   Hartlepool
# ...                                ...                          ...
# 2643                         W06000024               Merthyr Tydfil
# 2644                         W06000024               Merthyr Tydfil
# 2645                         W06000024               Merthyr Tydfil
# 2646                         W06000024               Merthyr Tydfil
# 2647                         W06000024               Merthyr Tydfil
#
#       Highest level of qualification (8 categories) Code  \
# 0                                                    -8
# ...

# %%
df.isna().sum()
# Out:
# Lower tier local authorities Code                     0
# Lower tier local authorities                          0
# Highest level of qualification (8 categories) Code    0
# Highest level of qualification (8 categories)         0
# Observation                                           0
# dtype: int64

# %%
df['Highest level of qualification (8 categories) Code'].unique()
# Out:
# array([-8,  0,  1,  2,  3,  4,  5,  6])

# %%
df_high = df[df['Highest level of qualification (8 categories) Code'] == 5]

# %%
df_high = df_high.drop(columns =['Highest level of qualification (8 categories)'])

# %%
df_high
# Out:
#      Lower tier local authorities Code Lower tier local authorities  \
# 6                            E06000001                   Hartlepool
# 14                           E06000002                Middlesbrough
# 22                           E06000003         Redcar and Cleveland
# 30                           E06000004             Stockton-on-Tees
# 38                           E06000005                   Darlington
# ...                                ...                          ...
# 2614                         W06000020                      Torfaen
# 2622                         W06000021                Monmouthshire
# 2630                         W06000022                      Newport
# 2638                         W06000023                        Powys
# 2646                         W06000024               Merthyr Tydfil
#
#       Highest level of qualification (8 categories) Code  Observation
# 6                                                     5         18526
# ...

# %%
df_high.to_csv('qualification_data.csv', index = False)

# %% [markdown]
# # II part

# %%
df = pd.read_csv("TS067-2021-3-filtered-2025-05-27T13_44_36Z.csv")
df
# Out:
#        Lower layer Super Output Areas Code Lower layer Super Output Areas  \
# 0                                E01000001            City of London 001A
# 1                                E01000001            City of London 001A
# 2                                E01000001            City of London 001A
# 3                                E01000001            City of London 001A
# 4                                E01000001            City of London 001A
# ...                                    ...                            ...
# 285371                           W01002040         Vale of Glamorgan 015F
# 285372                           W01002040         Vale of Glamorgan 015F
# 285373                           W01002040         Vale of Glamorgan 015F
# 285374                           W01002040         Vale of Glamorgan 015F
# 285375                           W01002040         Vale of Glamorgan 015F
#
#         Highest level of qualification (8 categories) Code  \
# ...

# %%
df.isna().sum()
# Out:
# Lower layer Super Output Areas Code                   0
# Lower layer Super Output Areas                        0
# Highest level of qualification (8 categories) Code    0
# Highest level of qualification (8 categories)         0
# Observation                                           0
# dtype: int64

# %%
df_high = df[df['Highest level of qualification (8 categories) Code'] == 5]

# %%
df_high = df_high.drop(columns =['Highest level of qualification (8 categories)'])

# %%
df_high
# Out:
#        Lower layer Super Output Areas Code Lower layer Super Output Areas  \
# 6                                E01000001            City of London 001A
# 14                               E01000002            City of London 001B
# 22                               E01000003            City of London 001C
# 30                               E01000005            City of London 001E
# 38                               E01000006      Barking and Dagenham 016A
# ...                                    ...                            ...
# 285342                           W01002036         Vale of Glamorgan 005G
# 285350                           W01002037         Vale of Glamorgan 005H
# 285358                           W01002038         Vale of Glamorgan 014G
# 285366                           W01002039         Vale of Glamorgan 014H
# 285374                           W01002040         Vale of Glamorgan 015F
#
#         Highest level of qualification (8 categories) Code  Observation
# ...

# %%
df_for_GIS = df_high.drop(columns = ['Lower layer Super Output Areas', 'Highest level of qualification (8 categories) Code'])

# %%
df_for_GIS = df_for_GIS.rename(columns = {'Lower layer Super Output Areas Code': 'LSOA21CD'})

# %%
df_for_GIS.to_csv('qualification_data.csv', index = False)
